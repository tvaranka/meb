# %%
import meb
from meb import utils
from meb import datasets
from meb import core
from meb import models

from functools import partial
from typing import List, Tuple

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
from torchvision import transforms
import timm
from tqdm import tqdm
from sklearn.svm import SVC
from sklearn.multioutput import MultiOutputClassifier



pd.set_option("display.max_columns", 50)
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# This notebook uses the traditional_methods.py file that requires dlib and numba. You can install them by including the optinal flag
#
# `
# pip install .[optional]
# `
#
# The dlib model for landmarks `shape_predictor_68_face_landmarks.dat` should be located in the data folder

# %% [markdown]
# ## Defining handcrafted validation

# %%
class HandCraftedCrossValidator(core.CrossDatasetValidator):
    def __init__(self, config: core.Config, verbose: bool = True):
        super().__init__(config)
        self.verbose = verbose
        
    def train_model(
        self, train_data: np.ndarray, train_labels: np.ndarray
        ) -> None:
        self.model.fit(train_data, train_labels)
        
    def evaluate_model(
        self, data: np.ndarray, labels: np.ndarray, test: bool = False
        ) -> List[float] |Tuple[List[float] | torch.tensor]:
        predictions = self.model.predict(data)
        results = self.evaluation_fn(torch.tensor(labels), torch.tensor(predictions))
        if test:
            return results, torch.tensor(predictions)
        return results
        
    def validate_split(self, df: pd.DataFrame, input_data: np.ndarray, labels: np.ndarray, split_name: str):
        """Main setup of each split. Should be called by the overriden validate method."""
        train_data, train_labels, test_data, test_labels = self.split_data(
            df[self.split_column], input_data, labels, split_name
        )
        self.model = self.cf.model()

        self.train_model(train_data, train_labels)
        train_metrics = self.evaluate_model(train_data, train_labels)
        test_metrics, outputs_test = self.evaluate_model(test_data, test_labels, test=True)
        return train_metrics, test_metrics, outputs_test

# %% [markdown]
# ## Constant

# %%
c = datasets.CrossDataset(ignore_validation=True)
df = c.data_frame
data = np.zeros((df.shape[0], 2))

# %%
class Constant:
    """Always predicts ones"""
    n_labels: int
    def fit(self, X, y):
        self.n_labels = y.shape[-1]
    
    def predict(self, X):
        return np.ones((X.shape[0], self.n_labels))

# %%
class Config(core.Config):
    action_units = utils.dataset_aus["cross"]
    evaluation_fn = [
        partial(utils.MultiLabelF1Score, average="macro"),
        partial(utils.MultiLabelF1Score, average="binary")
    ]
    model = Constant

# %%
HandCraftedCrossValidator(Config).validate_n_times(df, data)
# Out:
#   0%|                                                     | 0/5 [00:00<?, ?it/s]
# MultiLabelF1Score
# Dataset: casme, n=189 | train_mean: 0.08937 | test_mean: 0.0804
# Test per AU: [('AU1', 10.85), ('AU2', 8.25), ('AU4', 27.03), ('AU5', 0.0), ('AU6', 0.53), ('AU7', 2.07), ('AU9', 17.47), ('AU10', 1.56), ('AU12', 4.55), ('AU14', 10.85), ('AU15', 6.9), ('AU17', 6.44)]
#
# MultiLabelF1Score
# Dataset: casme, n=189 | train_mean: 0.1787 | test_mean: 0.1608
# Test per AU: [('AU1', 21.7), ('AU2', 16.5), ('AU4', 54.05), ('AU5', 0.0), ('AU6', 1.05), ('AU7', 4.15), ('AU9', 34.93), ('AU10', 3.12), ('AU12', 9.09), ('AU14', 21.7), ('AU15', 13.79), ('AU17', 12.87)]
#
# MultiLabelF1Score
# Dataset: casme2, n=256 | train_mean: 0.08736 | test_mean: 0.097
# Test per AU: [('AU1', 9.22), ('AU2', 7.91), ('AU4', 33.68), ('AU5', 0.78), ('AU6', 4.83), ('AU7', 13.22), ('AU9', 4.83), ('AU10', 5.88), ('AU12', 11.72), ('AU14', 9.54), ('AU15', 5.88), ('AU17', 8.9)]
#
# MultiLabelF1Score
# Dataset: casme2, n=256 | train_mean: 0.1747 | test_mean: 0.194
# Test per AU: [('AU1', 18.44), ('AU2', 15.83), ('AU4', 67.36), ('AU5', 1.55), ('AU6', 9.67), ('AU7', 26.44), ('AU9', 9.67), ('AU10', 11.76), ('AU12', 23.45), ('AU14', 19.08), ('AU15', 11.76), ('AU17', 17.79)]
#
# MultiLabelF1Score
# Dataset: samm, n=159 | train_mean: 0.08947 | test_mean: 0.07663
# Test per AU: [('AU1', 3.64), ('AU2', 10.17), ('AU4', 12.64), ('AU5', 5.92), ('AU6', 1.85), ('AU7', 22.44), ('AU9', 3.05), ('AU10', 3.64), ('AU12', 14.97), ('AU14', 7.56), ('AU15', 2.45), ('AU17', 3.64)]
#
# MultiLabelF1Score
# Dataset: samm, n=159 | train_mean: 0.1789 | test_mean: 0.1533
# Test per AU: [('AU1', 7.27), ('AU2', 20.34), ('AU4', 25.27), ('AU5', 11.83), ('AU6', 3.7), ('AU7', 44.88), ('AU9', 6.1), ('AU10', 7.27), ('AU12', 29.95), ('AU14', 15.12), ('AU15', 4.91), ('AU17', 7.27)]
#
# MultiLabelF1Score
# Dataset: fourd, n=267 | train_mean: 0.0862 | test_mean: 0.1008
# Test per AU: [('AU1', 14.7), ('AU2', 16.82), ('AU4', 27.64), ('AU5', 2.91), ('AU6', 8.56), ('AU7', 25.0), ('AU9', 0.37), ('AU10', 0.74), ('AU12', 16.56), ('AU14', 1.48), ('AU15', 2.2), ('AU17', 3.96)]
#
# MultiLabelF1Score
# Dataset: fourd, n=267 | train_mean: 0.1724 | test_mean: 0.2016
# Test per AU: [('AU1', 29.39), ('AU2', 33.64), ('AU4', 55.28), ('AU5', 5.82), ('AU6', 17.12), ('AU7', 50.0), ('AU9', 0.75), ('AU10', 1.49), ('AU12', 33.12), ('AU14', 2.95), ('AU15', 4.4), ('AU17', 7.91)]
#
# MultiLabelF1Score
# Dataset: mmew, n=300 | train_mean: 0.08571 | test_mean: 0.1036
# Test per AU: [('AU1', 14.29), ('AU2', 12.02), ('AU4', 26.65), ('AU5', 18.92), ('AU6', 3.23), ('AU7', 13.54), ('AU9', 2.6), ('AU10', 11.24), ('AU12', 10.98), ('AU14', 5.36), ('AU15', 1.96), ('AU17', 3.54)]
#
# MultiLabelF1Score
# Dataset: mmew, n=300 | train_mean: 0.1714 | test_mean: 0.2072
# Test per AU: [('AU1', 28.57), ('AU2', 24.05), ('AU4', 53.3), ('AU5', 37.84), ('AU6', 6.45), ('AU7', 27.09), ('AU9', 5.19), ('AU10', 22.49), ('AU12', 21.96), ('AU14', 10.73), ('AU15', 3.92), ('AU17', 7.07)]
#
# MultiLabelF1Score
# Dataset: casme3a, n=860 | train_mean: 0.09669 | test_mean: 0.07559
# Test per AU: [('AU1', 15.1), ('AU2', 12.96), ('AU4', 24.16), ('AU5', 4.87), ('AU6', 0.92), ('AU7', 3.04), ('AU9', 5.49), ('AU10', 1.15), ('AU12', 1.71), ('AU14', 18.33), ('AU15', 0.69), ('AU17', 2.27)]
#
# MultiLabelF1Score
# Dataset: casme3a, n=860 | train_mean: 0.1934 | test_mean: 0.1512
# Test per AU: [('AU1', 30.21), ('AU2', 25.91), ('AU4', 48.32), ('AU5', 9.73), ('AU6', 1.84), ('AU7', 6.09), ('AU9', 10.99), ('AU10', 2.3), ('AU12', 3.43), ('AU14', 36.66), ('AU15', 1.39), ('AU17', 4.55)]
#
# Final results
#
# MultiLabelF1Score
# All AUs:  [('AU1', 13.02), ('AU2', 12.12), ('AU4', 25.85), ('AU5', 6.19), ('AU6', 2.87), ('AU7', 11.04), ('AU9', 5.45), ('AU10', 3.56), ('AU12', 7.97), ('AU14', 12.0), ('AU15', 2.5), ('AU17', 4.06)]
# Mean:  8.89
#
#
# MultiLabelF1Score
# All AUs:  [('AU1', 26.04), ('AU2', 24.23), ('AU4', 51.7), ('AU5', 12.38), ('AU6', 5.74), ('AU7', 22.08), ('AU9', 10.89), ('AU10', 7.12), ('AU12', 15.95), ('AU14', 24.0), ('AU15', 4.99), ('AU17', 8.12)]
# Mean:  17.77
#  20%|█████████                                    | 1/5 [00:00<00:03,  1.33it/s]
# MultiLabelF1Score
# Dataset: casme, n=189 | train_mean: 0.08937 | test_mean: 0.0804
# Test per AU: [('AU1', 10.85), ('AU2', 8.25), ('AU4', 27.03), ('AU5', 0.0), ('AU6', 0.53), ('AU7', 2.07), ('AU9', 17.47), ('AU10', 1.56), ('AU12', 4.55), ('AU14', 10.85), ('AU15', 6.9), ('AU17', 6.44)]
#
# MultiLabelF1Score
# Dataset: casme, n=189 | train_mean: 0.1787 | test_mean: 0.1608
# Test per AU: [('AU1', 21.7), ('AU2', 16.5), ('AU4', 54.05), ('AU5', 0.0), ('AU6', 1.05), ('AU7', 4.15), ('AU9', 34.93), ('AU10', 3.12), ('AU12', 9.09), ('AU14', 21.7), ('AU15', 13.79), ('AU17', 12.87)]
#
# MultiLabelF1Score
# Dataset: casme2, n=256 | train_mean: 0.08736 | test_mean: 0.097
# Test per AU: [('AU1', 9.22), ('AU2', 7.91), ('AU4', 33.68), ('AU5', 0.78), ('AU6', 4.83), ('AU7', 13.22), ('AU9', 4.83), ('AU10', 5.88), ('AU12', 11.72), ('AU14', 9.54), ('AU15', 5.88), ('AU17', 8.9)]
#
# MultiLabelF1Score
# Dataset: casme2, n=256 | train_mean: 0.1747 | test_mean: 0.194
# Test per AU: [('AU1', 18.44), ('AU2', 15.83), ('AU4', 67.36), ('AU5', 1.55), ('AU6', 9.67), ('AU7', 26.44), ('AU9', 9.67), ('AU10', 11.76), ('AU12', 23.45), ('AU14', 19.08), ('AU15', 11.76), ('AU17', 17.79)]
#
# MultiLabelF1Score
# Dataset: samm, n=159 | train_mean: 0.08947 | test_mean: 0.07663
# Test per AU: [('AU1', 3.64), ('AU2', 10.17), ('AU4', 12.64), ('AU5', 5.92), ('AU6', 1.85), ('AU7', 22.44), ('AU9', 3.05), ('AU10', 3.64), ('AU12', 14.97), ('AU14', 7.56), ('AU15', 2.45), ('AU17', 3.64)]
#
# MultiLabelF1Score
# Dataset: samm, n=159 | train_mean: 0.1789 | test_mean: 0.1533
# Test per AU: [('AU1', 7.27), ('AU2', 20.34), ('AU4', 25.27), ('AU5', 11.83), ('AU6', 3.7), ('AU7', 44.88), ('AU9', 6.1), ('AU10', 7.27), ('AU12', 29.95), ('AU14', 15.12), ('AU15', 4.91), ('AU17', 7.27)]
#
# MultiLabelF1Score
# Dataset: fourd, n=267 | train_mean: 0.0862 | test_mean: 0.1008
# Test per AU: [('AU1', 14.7), ('AU2', 16.82), ('AU4', 27.64), ('AU5', 2.91), ('AU6', 8.56), ('AU7', 25.0), ('AU9', 0.37), ('AU10', 0.74), ('AU12', 16.56), ('AU14', 1.48), ('AU15', 2.2), ('AU17', 3.96)]
#
# MultiLabelF1Score
# Dataset: fourd, n=267 | train_mean: 0.1724 | test_mean: 0.2016
# Test per AU: [('AU1', 29.39), ('AU2', 33.64), ('AU4', 55.28), ('AU5', 5.82), ('AU6', 17.12), ('AU7', 50.0), ('AU9', 0.75), ('AU10', 1.49), ('AU12', 33.12), ('AU14', 2.95), ('AU15', 4.4), ('AU17', 7.91)]
#
# MultiLabelF1Score
# Dataset: mmew, n=300 | train_mean: 0.08571 | test_mean: 0.1036
# Test per AU: [('AU1', 14.29), ('AU2', 12.02), ('AU4', 26.65), ('AU5', 18.92), ('AU6', 3.23), ('AU7', 13.54), ('AU9', 2.6), ('AU10', 11.24), ('AU12', 10.98), ('AU14', 5.36), ('AU15', 1.96), ('AU17', 3.54)]
#
# MultiLabelF1Score
# Dataset: mmew, n=300 | train_mean: 0.1714 | test_mean: 0.2072
# Test per AU: [('AU1', 28.57), ('AU2', 24.05), ('AU4', 53.3), ('AU5', 37.84), ('AU6', 6.45), ('AU7', 27.09), ('AU9', 5.19), ('AU10', 22.49), ('AU12', 21.96), ('AU14', 10.73), ('AU15', 3.92), ('AU17', 7.07)]
#
# MultiLabelF1Score
# Dataset: casme3a, n=860 | train_mean: 0.09669 | test_mean: 0.07559
# Test per AU: [('AU1', 15.1), ('AU2', 12.96), ('AU4', 24.16), ('AU5', 4.87), ('AU6', 0.92), ('AU7', 3.04), ('AU9', 5.49), ('AU10', 1.15), ('AU12', 1.71), ('AU14', 18.33), ('AU15', 0.69), ('AU17', 2.27)]
#
# MultiLabelF1Score
# Dataset: casme3a, n=860 | train_mean: 0.1934 | test_mean: 0.1512
# Test per AU: [('AU1', 30.21), ('AU2', 25.91), ('AU4', 48.32), ('AU5', 9.73), ('AU6', 1.84), ('AU7', 6.09), ('AU9', 10.99), ('AU10', 2.3), ('AU12', 3.43), ('AU14', 36.66), ('AU15', 1.39), ('AU17', 4.55)]
#
# Final results
#
# MultiLabelF1Score
# All AUs:  [('AU1', 13.02), ('AU2', 12.12), ('AU4', 25.85), ('AU5', 6.19), ('AU6', 2.87), ('AU7', 11.04), ('AU9', 5.45), ('AU10', 3.56), ('AU12', 7.97), ('AU14', 12.0), ('AU15', 2.5), ('AU17', 4.06)]
# Mean:  8.89
#
#
# MultiLabelF1Score
# All AUs:  [('AU1', 26.04), ('AU2', 24.23), ('AU4', 51.7), ('AU5', 12.38), ('AU6', 5.74), ('AU7', 22.08), ('AU9', 10.89), ('AU10', 7.12), ('AU12', 15.95), ('AU14', 24.0), ('AU15', 4.99), ('AU17', 8.12)]
# Mean:  17.77
#  40%|██████████████████                           | 2/5 [00:01<00:02,  1.33it/s]
# MultiLabelF1Score
# Dataset: casme, n=189 | train_mean: 0.08937 | test_mean: 0.0804
# Test per AU: [('AU1', 10.85), ('AU2', 8.25), ('AU4', 27.03), ('AU5', 0.0), ('AU6', 0.53), ('AU7', 2.07), ('AU9', 17.47), ('AU10', 1.56), ('AU12', 4.55), ('AU14', 10.85), ('AU15', 6.9), ('AU17', 6.44)]
#
# MultiLabelF1Score
# Dataset: casme, n=189 | train_mean: 0.1787 | test_mean: 0.1608
# Test per AU: [('AU1', 21.7), ('AU2', 16.5), ('AU4', 54.05), ('AU5', 0.0), ('AU6', 1.05), ('AU7', 4.15), ('AU9', 34.93), ('AU10', 3.12), ('AU12', 9.09), ('AU14', 21.7), ('AU15', 13.79), ('AU17', 12.87)]
#
# MultiLabelF1Score
# Dataset: casme2, n=256 | train_mean: 0.08736 | test_mean: 0.097
# Test per AU: [('AU1', 9.22), ('AU2', 7.91), ('AU4', 33.68), ('AU5', 0.78), ('AU6', 4.83), ('AU7', 13.22), ('AU9', 4.83), ('AU10', 5.88), ('AU12', 11.72), ('AU14', 9.54), ('AU15', 5.88), ('AU17', 8.9)]
#
# MultiLabelF1Score
# Dataset: casme2, n=256 | train_mean: 0.1747 | test_mean: 0.194
# Test per AU: [('AU1', 18.44), ('AU2', 15.83), ('AU4', 67.36), ('AU5', 1.55), ('AU6', 9.67), ('AU7', 26.44), ('AU9', 9.67), ('AU10', 11.76), ('AU12', 23.45), ('AU14', 19.08), ('AU15', 11.76), ('AU17', 17.79)]
#
# MultiLabelF1Score
# Dataset: samm, n=159 | train_mean: 0.08947 | test_mean: 0.07663
# Test per AU: [('AU1', 3.64), ('AU2', 10.17), ('AU4', 12.64), ('AU5', 5.92), ('AU6', 1.85), ('AU7', 22.44), ('AU9', 3.05), ('AU10', 3.64), ('AU12', 14.97), ('AU14', 7.56), ('AU15', 2.45), ('AU17', 3.64)]
#
# MultiLabelF1Score
# Dataset: samm, n=159 | train_mean: 0.1789 | test_mean: 0.1533
# Test per AU: [('AU1', 7.27), ('AU2', 20.34), ('AU4', 25.27), ('AU5', 11.83), ('AU6', 3.7), ('AU7', 44.88), ('AU9', 6.1), ('AU10', 7.27), ('AU12', 29.95), ('AU14', 15.12), ('AU15', 4.91), ('AU17', 7.27)]
#
# MultiLabelF1Score
# Dataset: fourd, n=267 | train_mean: 0.0862 | test_mean: 0.1008
# Test per AU: [('AU1', 14.7), ('AU2', 16.82), ('AU4', 27.64), ('AU5', 2.91), ('AU6', 8.56), ('AU7', 25.0), ('AU9', 0.37), ('AU10', 0.74), ('AU12', 16.56), ('AU14', 1.48), ('AU15', 2.2), ('AU17', 3.96)]
#
# MultiLabelF1Score
# Dataset: fourd, n=267 | train_mean: 0.1724 | test_mean: 0.2016
# Test per AU: [('AU1', 29.39), ('AU2', 33.64), ('AU4', 55.28), ('AU5', 5.82), ('AU6', 17.12), ('AU7', 50.0), ('AU9', 0.75), ('AU10', 1.49), ('AU12', 33.12), ('AU14', 2.95), ('AU15', 4.4), ('AU17', 7.91)]
#
# MultiLabelF1Score
# Dataset: mmew, n=300 | train_mean: 0.08571 | test_mean: 0.1036
# Test per AU: [('AU1', 14.29), ('AU2', 12.02), ('AU4', 26.65), ('AU5', 18.92), ('AU6', 3.23), ('AU7', 13.54), ('AU9', 2.6), ('AU10', 11.24), ('AU12', 10.98), ('AU14', 5.36), ('AU15', 1.96), ('AU17', 3.54)]
#
# MultiLabelF1Score
# Dataset: mmew, n=300 | train_mean: 0.1714 | test_mean: 0.2072
# Test per AU: [('AU1', 28.57), ('AU2', 24.05), ('AU4', 53.3), ('AU5', 37.84), ('AU6', 6.45), ('AU7', 27.09), ('AU9', 5.19), ('AU10', 22.49), ('AU12', 21.96), ('AU14', 10.73), ('AU15', 3.92), ('AU17', 7.07)]
#
# MultiLabelF1Score
# Dataset: casme3a, n=860 | train_mean: 0.09669 | test_mean: 0.07559
# Test per AU: [('AU1', 15.1), ('AU2', 12.96), ('AU4', 24.16), ('AU5', 4.87), ('AU6', 0.92), ('AU7', 3.04), ('AU9', 5.49), ('AU10', 1.15), ('AU12', 1.71), ('AU14', 18.33), ('AU15', 0.69), ('AU17', 2.27)]
#
# MultiLabelF1Score
# Dataset: casme3a, n=860 | train_mean: 0.1934 | test_mean: 0.1512
# Test per AU: [('AU1', 30.21), ('AU2', 25.91), ('AU4', 48.32), ('AU5', 9.73), ('AU6', 1.84), ('AU7', 6.09), ('AU9', 10.99), ('AU10', 2.3), ('AU12', 3.43), ('AU14', 36.66), ('AU15', 1.39), ('AU17', 4.55)]
#
# Final results
#
# MultiLabelF1Score
# All AUs:  [('AU1', 13.02), ('AU2', 12.12), ('AU4', 25.85), ('AU5', 6.19), ('AU6', 2.87), ('AU7', 11.04), ('AU9', 5.45), ('AU10', 3.56), ('AU12', 7.97), ('AU14', 12.0), ('AU15', 2.5), ('AU17', 4.06)]
# Mean:  8.89
#
#
# MultiLabelF1Score
# All AUs:  [('AU1', 26.04), ('AU2', 24.23), ('AU4', 51.7), ('AU5', 12.38), ('AU6', 5.74), ('AU7', 22.08), ('AU9', 10.89), ('AU10', 7.12), ('AU12', 15.95), ('AU14', 24.0), ('AU15', 4.99), ('AU17', 8.12)]
# Mean:  17.77
#  60%|███████████████████████████                  | 3/5 [00:02<00:01,  1.37it/s]
# MultiLabelF1Score
# Dataset: casme, n=189 | train_mean: 0.08937 | test_mean: 0.0804
# Test per AU: [('AU1', 10.85), ('AU2', 8.25), ('AU4', 27.03), ('AU5', 0.0), ('AU6', 0.53), ('AU7', 2.07), ('AU9', 17.47), ('AU10', 1.56), ('AU12', 4.55), ('AU14', 10.85), ('AU15', 6.9), ('AU17', 6.44)]
#
# MultiLabelF1Score
# Dataset: casme, n=189 | train_mean: 0.1787 | test_mean: 0.1608
# Test per AU: [('AU1', 21.7), ('AU2', 16.5), ('AU4', 54.05), ('AU5', 0.0), ('AU6', 1.05), ('AU7', 4.15), ('AU9', 34.93), ('AU10', 3.12), ('AU12', 9.09), ('AU14', 21.7), ('AU15', 13.79), ('AU17', 12.87)]
#
# MultiLabelF1Score
# Dataset: casme2, n=256 | train_mean: 0.08736 | test_mean: 0.097
# Test per AU: [('AU1', 9.22), ('AU2', 7.91), ('AU4', 33.68), ('AU5', 0.78), ('AU6', 4.83), ('AU7', 13.22), ('AU9', 4.83), ('AU10', 5.88), ('AU12', 11.72), ('AU14', 9.54), ('AU15', 5.88), ('AU17', 8.9)]
#
# MultiLabelF1Score
# Dataset: casme2, n=256 | train_mean: 0.1747 | test_mean: 0.194
# Test per AU: [('AU1', 18.44), ('AU2', 15.83), ('AU4', 67.36), ('AU5', 1.55), ('AU6', 9.67), ('AU7', 26.44), ('AU9', 9.67), ('AU10', 11.76), ('AU12', 23.45), ('AU14', 19.08), ('AU15', 11.76), ('AU17', 17.79)]
#
# MultiLabelF1Score
# Dataset: samm, n=159 | train_mean: 0.08947 | test_mean: 0.07663
# Test per AU: [('AU1', 3.64), ('AU2', 10.17), ('AU4', 12.64), ('AU5', 5.92), ('AU6', 1.85), ('AU7', 22.44), ('AU9', 3.05), ('AU10', 3.64), ('AU12', 14.97), ('AU14', 7.56), ('AU15', 2.45), ('AU17', 3.64)]
#
# MultiLabelF1Score
# Dataset: samm, n=159 | train_mean: 0.1789 | test_mean: 0.1533
# Test per AU: [('AU1', 7.27), ('AU2', 20.34), ('AU4', 25.27), ('AU5', 11.83), ('AU6', 3.7), ('AU7', 44.88), ('AU9', 6.1), ('AU10', 7.27), ('AU12', 29.95), ('AU14', 15.12), ('AU15', 4.91), ('AU17', 7.27)]
#
# MultiLabelF1Score
# Dataset: fourd, n=267 | train_mean: 0.0862 | test_mean: 0.1008
# Test per AU: [('AU1', 14.7), ('AU2', 16.82), ('AU4', 27.64), ('AU5', 2.91), ('AU6', 8.56), ('AU7', 25.0), ('AU9', 0.37), ('AU10', 0.74), ('AU12', 16.56), ('AU14', 1.48), ('AU15', 2.2), ('AU17', 3.96)]
#
# MultiLabelF1Score
# Dataset: fourd, n=267 | train_mean: 0.1724 | test_mean: 0.2016
# Test per AU: [('AU1', 29.39), ('AU2', 33.64), ('AU4', 55.28), ('AU5', 5.82), ('AU6', 17.12), ('AU7', 50.0), ('AU9', 0.75), ('AU10', 1.49), ('AU12', 33.12), ('AU14', 2.95), ('AU15', 4.4), ('AU17', 7.91)]
#
# MultiLabelF1Score
# Dataset: mmew, n=300 | train_mean: 0.08571 | test_mean: 0.1036
# Test per AU: [('AU1', 14.29), ('AU2', 12.02), ('AU4', 26.65), ('AU5', 18.92), ('AU6', 3.23), ('AU7', 13.54), ('AU9', 2.6), ('AU10', 11.24), ('AU12', 10.98), ('AU14', 5.36), ('AU15', 1.96), ('AU17', 3.54)]
#
# MultiLabelF1Score
# Dataset: mmew, n=300 | train_mean: 0.1714 | test_mean: 0.2072
# Test per AU: [('AU1', 28.57), ('AU2', 24.05), ('AU4', 53.3), ('AU5', 37.84), ('AU6', 6.45), ('AU7', 27.09), ('AU9', 5.19), ('AU10', 22.49), ('AU12', 21.96), ('AU14', 10.73), ('AU15', 3.92), ('AU17', 7.07)]
#
# MultiLabelF1Score
# Dataset: casme3a, n=860 | train_mean: 0.09669 | test_mean: 0.07559
# Test per AU: [('AU1', 15.1), ('AU2', 12.96), ('AU4', 24.16), ('AU5', 4.87), ('AU6', 0.92), ('AU7', 3.04), ('AU9', 5.49), ('AU10', 1.15), ('AU12', 1.71), ('AU14', 18.33), ('AU15', 0.69), ('AU17', 2.27)]
#
# MultiLabelF1Score
# Dataset: casme3a, n=860 | train_mean: 0.1934 | test_mean: 0.1512
# Test per AU: [('AU1', 30.21), ('AU2', 25.91), ('AU4', 48.32), ('AU5', 9.73), ('AU6', 1.84), ('AU7', 6.09), ('AU9', 10.99), ('AU10', 2.3), ('AU12', 3.43), ('AU14', 36.66), ('AU15', 1.39), ('AU17', 4.55)]
#
# Final results
#
# MultiLabelF1Score
# All AUs:  [('AU1', 13.02), ('AU2', 12.12), ('AU4', 25.85), ('AU5', 6.19), ('AU6', 2.87), ('AU7', 11.04), ('AU9', 5.45), ('AU10', 3.56), ('AU12', 7.97), ('AU14', 12.0), ('AU15', 2.5), ('AU17', 4.06)]
# Mean:  8.89
#
#
# MultiLabelF1Score
# All AUs:  [('AU1', 26.04), ('AU2', 24.23), ('AU4', 51.7), ('AU5', 12.38), ('AU6', 5.74), ('AU7', 22.08), ('AU9', 10.89), ('AU10', 7.12), ('AU12', 15.95), ('AU14', 24.0), ('AU15', 4.99), ('AU17', 8.12)]
# Mean:  17.77
#  80%|████████████████████████████████████         | 4/5 [00:02<00:00,  1.40it/s]
# MultiLabelF1Score
# Dataset: casme, n=189 | train_mean: 0.08937 | test_mean: 0.0804
# Test per AU: [('AU1', 10.85), ('AU2', 8.25), ('AU4', 27.03), ('AU5', 0.0), ('AU6', 0.53), ('AU7', 2.07), ('AU9', 17.47), ('AU10', 1.56), ('AU12', 4.55), ('AU14', 10.85), ('AU15', 6.9), ('AU17', 6.44)]
#
# MultiLabelF1Score
# Dataset: casme, n=189 | train_mean: 0.1787 | test_mean: 0.1608
# Test per AU: [('AU1', 21.7), ('AU2', 16.5), ('AU4', 54.05), ('AU5', 0.0), ('AU6', 1.05), ('AU7', 4.15), ('AU9', 34.93), ('AU10', 3.12), ('AU12', 9.09), ('AU14', 21.7), ('AU15', 13.79), ('AU17', 12.87)]
#
# MultiLabelF1Score
# Dataset: casme2, n=256 | train_mean: 0.08736 | test_mean: 0.097
# Test per AU: [('AU1', 9.22), ('AU2', 7.91), ('AU4', 33.68), ('AU5', 0.78), ('AU6', 4.83), ('AU7', 13.22), ('AU9', 4.83), ('AU10', 5.88), ('AU12', 11.72), ('AU14', 9.54), ('AU15', 5.88), ('AU17', 8.9)]
#
# MultiLabelF1Score
# Dataset: casme2, n=256 | train_mean: 0.1747 | test_mean: 0.194
# Test per AU: [('AU1', 18.44), ('AU2', 15.83), ('AU4', 67.36), ('AU5', 1.55), ('AU6', 9.67), ('AU7', 26.44), ('AU9', 9.67), ('AU10', 11.76), ('AU12', 23.45), ('AU14', 19.08), ('AU15', 11.76), ('AU17', 17.79)]
#
# MultiLabelF1Score
# Dataset: samm, n=159 | train_mean: 0.08947 | test_mean: 0.07663
# Test per AU: [('AU1', 3.64), ('AU2', 10.17), ('AU4', 12.64), ('AU5', 5.92), ('AU6', 1.85), ('AU7', 22.44), ('AU9', 3.05), ('AU10', 3.64), ('AU12', 14.97), ('AU14', 7.56), ('AU15', 2.45), ('AU17', 3.64)]
#
# MultiLabelF1Score
# Dataset: samm, n=159 | train_mean: 0.1789 | test_mean: 0.1533
# Test per AU: [('AU1', 7.27), ('AU2', 20.34), ('AU4', 25.27), ('AU5', 11.83), ('AU6', 3.7), ('AU7', 44.88), ('AU9', 6.1), ('AU10', 7.27), ('AU12', 29.95), ('AU14', 15.12), ('AU15', 4.91), ('AU17', 7.27)]
#
# MultiLabelF1Score
# Dataset: fourd, n=267 | train_mean: 0.0862 | test_mean: 0.1008
# Test per AU: [('AU1', 14.7), ('AU2', 16.82), ('AU4', 27.64), ('AU5', 2.91), ('AU6', 8.56), ('AU7', 25.0), ('AU9', 0.37), ('AU10', 0.74), ('AU12', 16.56), ('AU14', 1.48), ('AU15', 2.2), ('AU17', 3.96)]
#
# MultiLabelF1Score
# Dataset: fourd, n=267 | train_mean: 0.1724 | test_mean: 0.2016
# Test per AU: [('AU1', 29.39), ('AU2', 33.64), ('AU4', 55.28), ('AU5', 5.82), ('AU6', 17.12), ('AU7', 50.0), ('AU9', 0.75), ('AU10', 1.49), ('AU12', 33.12), ('AU14', 2.95), ('AU15', 4.4), ('AU17', 7.91)]
#
# MultiLabelF1Score
# Dataset: mmew, n=300 | train_mean: 0.08571 | test_mean: 0.1036
# Test per AU: [('AU1', 14.29), ('AU2', 12.02), ('AU4', 26.65), ('AU5', 18.92), ('AU6', 3.23), ('AU7', 13.54), ('AU9', 2.6), ('AU10', 11.24), ('AU12', 10.98), ('AU14', 5.36), ('AU15', 1.96), ('AU17', 3.54)]
#
# MultiLabelF1Score
# Dataset: mmew, n=300 | train_mean: 0.1714 | test_mean: 0.2072
# Test per AU: [('AU1', 28.57), ('AU2', 24.05), ('AU4', 53.3), ('AU5', 37.84), ('AU6', 6.45), ('AU7', 27.09), ('AU9', 5.19), ('AU10', 22.49), ('AU12', 21.96), ('AU14', 10.73), ('AU15', 3.92), ('AU17', 7.07)]
#
# MultiLabelF1Score
# Dataset: casme3a, n=860 | train_mean: 0.09669 | test_mean: 0.07559
# Test per AU: [('AU1', 15.1), ('AU2', 12.96), ('AU4', 24.16), ('AU5', 4.87), ('AU6', 0.92), ('AU7', 3.04), ('AU9', 5.49), ('AU10', 1.15), ('AU12', 1.71), ('AU14', 18.33), ('AU15', 0.69), ('AU17', 2.27)]
#
# MultiLabelF1Score
# Dataset: casme3a, n=860 | train_mean: 0.1934 | test_mean: 0.1512
# Test per AU: [('AU1', 30.21), ('AU2', 25.91), ('AU4', 48.32), ('AU5', 9.73), ('AU6', 1.84), ('AU7', 6.09), ('AU9', 10.99), ('AU10', 2.3), ('AU12', 3.43), ('AU14', 36.66), ('AU15', 1.39), ('AU17', 4.55)]
#
# Final results
#
# MultiLabelF1Score
# All AUs:  [('AU1', 13.02), ('AU2', 12.12), ('AU4', 25.85), ('AU5', 6.19), ('AU6', 2.87), ('AU7', 11.04), ('AU9', 5.45), ('AU10', 3.56), ('AU12', 7.97), ('AU14', 12.0), ('AU15', 2.5), ('AU17', 4.06)]
# Mean:  8.89
#
#
# MultiLabelF1Score
# All AUs:  [('AU1', 26.04), ('AU2', 24.23), ('AU4', 51.7), ('AU5', 12.38), ('AU6', 5.74), ('AU7', 22.08), ('AU9', 10.89), ('AU10', 7.12), ('AU12', 15.95), ('AU14', 24.0), ('AU15', 4.99), ('AU17', 8.12)]
# Mean:  17.77
# 100%|█████████████████████████████████████████████| 5/5 [00:03<00:00,  1.39it/s]
# MultiLabelF1Score
# AUS: ['AU1', 'AU2', 'AU4', 'AU5', 'AU6', 'AU7', 'AU9', 'AU10', 'AU12', 'AU14', 'AU15', 'AU17', 'Average']
# 13.0 & 12.1 & 25.8 & 6.2 & 2.9 & 11.0 & 5.4 & 3.6 & 8.0 & 12.0 & 2.5 & 4.1 & 8.9
#
# Datasets:  ['casme', 'casme2', 'samm', 'fourd', 'mmew', 'casme3a', 'Average']
# 8.0 & 9.7 & 7.7 & 10.1 & 10.4 & 7.6 & 8.9
# MultiLabelF1Score
# AUS: ['AU1', 'AU2', 'AU4', 'AU5', 'AU6', 'AU7', 'AU9', 'AU10', 'AU12', 'AU14', 'AU15', 'AU17', 'Average']
# 26.0 & 24.2 & 51.7 & 12.4 & 5.7 & 22.1 & 10.9 & 7.1 & 15.9 & 24.0 & 5.0 & 8.1 & 17.8
#
# Datasets:  ['casme', 'casme2', 'samm', 'fourd', 'mmew', 'casme3a', 'Average']
# 16.1 & 19.4 & 15.3 & 20.2 & 20.7 & 15.1 & 17.8

# %% [markdown]
# # SVM + OF

# %%
c = datasets.CrossDataset(resize=32, optical_flow=True)
df = c.data_frame
data = c.data

# %%
class Config(core.Config):
    action_units = utils.dataset_aus["cross"]
    evaluation_fn = [
        partial(utils.MultiLabelF1Score, average="macro"),
        partial(utils.MultiLabelF1Score, average="binary")
    ]
    # Multioutput classifiers for multi-label
    model = partial(MultiOutputClassifier, SVC(C=28))

# %%
HandCraftedCrossValidator(Config).validate_n_times(df, data.reshape(2031, -1))
# Out:
# 100%|████████████████████████████████████████████| 5/5 [22:14<00:00, 266.88s/it]
# MultiLabelF1Score
# AUS: ['AU1', 'AU2', 'AU4', 'AU5', 'AU6', 'AU7', 'AU9', 'AU10', 'AU12', 'AU14', 'AU15', 'AU17', 'Average']
# 83.3 & 80.5 & 88.0 & 54.7 & 54.3 & 68.8 & 56.8 & 54.1 & 60.5 & 65.9 & 58.1 & 65.0 & 65.8
#
# Datasets:  ['casme', 'casme2', 'samm', 'fourd', 'mmew', 'casme3a', 'Average']
# 63.1 & 69.5 & 67.3 & 63.1 & 63.2 & 64.4 & 65.1
# MultiLabelF1Score
# AUS: ['AU1', 'AU2', 'AU4', 'AU5', 'AU6', 'AU7', 'AU9', 'AU10', 'AU12', 'AU14', 'AU15', 'AU17', 'Average']
# 71.0 & 65.9 & 84.2 & 13.6 & 10.6 & 44.4 & 17.2 & 10.3 & 26.7 & 39.1 & 18.2 & 32.7 & 36.2
#
# Datasets:  ['casme', 'casme2', 'samm', 'fourd', 'mmew', 'casme3a', 'Average']
# 31.9 & 42.8 & 38.7 & 31.5 & 31.6 & 33.1 & 34.9

# %%
out = HandCraftedCrossValidator(Config).validate(df, data.reshape(2031, -1))
# Out:
# MultiLabelF1Score
# Dataset: casme, n=189 | train_mean: 1.0 | test_mean: 0.601
# Test per AU: [('AU1', 72.84), ('AU2', 81.74), ('AU4', 69.71), ('AU5', 43.75), ('AU6', 48.64), ('AU7', 46.65), ('AU9', 68.3), ('AU10', 47.06), ('AU12', 54.66), ('AU14', 58.97), ('AU15', 68.25), ('AU17', 60.65)]
#
# MultiLabelF1Score
# Dataset: casme, n=189 | train_mean: 1.0 | test_mean: 0.2907
# Test per AU: [('AU1', 51.28), ('AU2', 66.67), ('AU4', 62.5), ('AU5', 0.0), ('AU6', 0.0), ('AU7', 4.88), ('AU9', 46.67), ('AU10', 0.0), ('AU12', 20.83), ('AU14', 28.57), ('AU15', 41.38), ('AU17', 26.09)]
#
# MultiLabelF1Score
# Dataset: casme2, n=256 | train_mean: 1.0 | test_mean: 0.7018
# Test per AU: [('AU1', 87.9), ('AU2', 81.95), ('AU4', 89.45), ('AU5', 49.31), ('AU6', 70.81), ('AU7', 70.52), ('AU9', 53.94), ('AU10', 53.54), ('AU12', 73.21), ('AU14', 67.43), ('AU15', 76.25), ('AU17', 67.8)]
#
# MultiLabelF1Score
# Dataset: casme2, n=256 | train_mean: 1.0 | test_mean: 0.4525
# Test per AU: [('AU1', 78.69), ('AU2', 67.86), ('AU4', 89.33), ('AU5', 0.0), ('AU6', 45.16), ('AU7', 50.6), ('AU9', 11.11), ('AU10', 10.53), ('AU12', 53.12), ('AU14', 42.11), ('AU15', 54.55), ('AU17', 40.0)]
#
# MultiLabelF1Score
# Dataset: samm, n=159 | train_mean: 1.0 | test_mean: 0.6922
# Test per AU: [('AU1', 63.95), ('AU2', 83.18), ('AU4', 77.4), ('AU5', 63.95), ('AU6', 48.71), ('AU7', 78.59), ('AU9', 65.36), ('AU10', 82.85), ('AU12', 63.47), ('AU14', 59.88), ('AU15', 71.41), ('AU17', 71.93)]
#
# MultiLabelF1Score
# Dataset: samm, n=159 | train_mean: 1.0 | test_mean: 0.4395
# Test per AU: [('AU1', 33.33), ('AU2', 70.27), ('AU4', 63.33), ('AU5', 33.33), ('AU6', 0.0), ('AU7', 69.57), ('AU9', 33.33), ('AU10', 66.67), ('AU12', 35.9), ('AU14', 31.11), ('AU15', 44.44), ('AU17', 46.15)]
#
# MultiLabelF1Score
# Dataset: fourd, n=267 | train_mean: 1.0 | test_mean: 0.6282
# Test per AU: [('AU1', 80.6), ('AU2', 76.91), ('AU4', 85.61), ('AU5', 51.0), ('AU6', 54.77), ('AU7', 67.44), ('AU9', 57.38), ('AU10', 49.34), ('AU12', 60.2), ('AU14', 49.51), ('AU15', 58.23), ('AU17', 62.82)]
#
# MultiLabelF1Score
# Dataset: fourd, n=267 | train_mean: 1.0 | test_mean: 0.3222
# Test per AU: [('AU1', 67.44), ('AU2', 61.18), ('AU4', 82.0), ('AU5', 7.14), ('AU6', 14.29), ('AU7', 50.0), ('AU9', 16.67), ('AU10', 0.0), ('AU12', 30.99), ('AU14', 10.17), ('AU15', 18.18), ('AU17', 28.57)]
#
# MultiLabelF1Score
# Dataset: mmew, n=300 | train_mean: 1.0 | test_mean: 0.6135
# Test per AU: [('AU1', 85.37), ('AU2', 82.87), ('AU4', 75.21), ('AU5', 51.37), ('AU6', 49.07), ('AU7', 53.68), ('AU9', 51.52), ('AU10', 53.92), ('AU12', 56.07), ('AU14', 70.29), ('AU15', 48.81), ('AU17', 58.06)]
#
# MultiLabelF1Score
# Dataset: mmew, n=300 | train_mean: 1.0 | test_mean: 0.2889
# Test per AU: [('AU1', 75.27), ('AU2', 70.59), ('AU4', 65.96), ('AU5', 15.38), ('AU6', 0.0), ('AU7', 15.38), ('AU9', 7.41), ('AU10', 14.29), ('AU12', 19.61), ('AU14', 43.75), ('AU15', 0.0), ('AU17', 19.05)]
#
# MultiLabelF1Score
# Dataset: casme3a, n=860 | train_mean: 1.0 | test_mean: 0.6029
# Test per AU: [('AU1', 79.64), ('AU2', 69.09), ('AU4', 89.42), ('AU5', 50.34), ('AU6', 52.62), ('AU7', 56.69), ('AU9', 54.38), ('AU10', 55.87), ('AU12', 48.32), ('AU14', 61.34), ('AU15', 49.86), ('AU17', 55.88)]
#
# MultiLabelF1Score
# Dataset: casme3a, n=860 | train_mean: 1.0 | test_mean: 0.2719
# Test per AU: [('AU1', 65.96), ('AU2', 46.91), ('AU4', 85.91), ('AU5', 7.14), ('AU6', 8.0), ('AU7', 21.38), ('AU9', 13.48), ('AU10', 13.95), ('AU12', 6.98), ('AU14', 36.12), ('AU15', 3.28), ('AU17', 17.14)]
#
# Final results
#
# MultiLabelF1Score
# All AUs:  [('AU1', 80.53), ('AU2', 75.72), ('AU4', 84.63), ('AU5', 51.69), ('AU6', 56.49), ('AU7', 64.41), ('AU9', 59.28), ('AU10', 55.55), ('AU12', 56.72), ('AU14', 61.51), ('AU15', 59.5), ('AU17', 60.25)]
# Mean:  63.86
#
#
# MultiLabelF1Score
# All AUs:  [('AU1', 66.67), ('AU2', 57.88), ('AU4', 80.0), ('AU5', 10.31), ('AU6', 15.94), ('AU7', 38.48), ('AU9', 22.94), ('AU10', 14.18), ('AU12', 22.92), ('AU14', 33.27), ('AU15', 21.92), ('AU17', 24.77)]
# Mean:  34.11

# %% [markdown]
# # MDMO

# %%
from meb.utils import traditional_methods as tm

# %%
c = datasets.CrossDataset(resize=112, cropped=True)
df = c.data_frame
data = c.data
# Out:
# Warning:             The number of frames does not correspond for the sample             spNO.170_k
# Warning:             The number of frames does not correspond for the sample             spNO.171_e
# Warning:             The number of frames does not correspond for the sample             spNO.171_e2
# Warning:             The number of frames does not correspond for the sample             spNO.171_f
# Warning:             The number of frames does not correspond for the sample             spNO.171_f2
# Warning:             The number of frames does not correspond for the sample             spNO.171_h2
# Warning:             The number of frames does not correspond for the sample             spNO.171_h3
# Warning:             The number of frames does not correspond for the sample             spNO.171_h4
# Warning:             The number of frames does not correspond for the sample             spNO.171_h5
# Warning:             The number of frames does not correspond for the sample             spNO.171_l
# Warning:             The number of frames does not correspond for the sample             spNO.172_f
# Warning:             The number of frames does not correspond for the sample             spNO.172_k
# Warning:             The number of frames does not correspond for the sample             spNO.172_k3
# Warning:             The number of frames does not correspond for the sample             spNO.174_e
# Warning:             The number of frames does not correspond for the sample             spNO.202_m
# Warning:             The number of frames does not correspond for the sample             spNO.202_m2
# Warning:             The number of frames does not correspond for the sample             spNO.206_d
# Warning:             The number of frames does not correspond for the sample             spNO.206_e2
# Warning:             The number of frames does not correspond for the sample             spNO.206_e3
# Warning:             The number of frames does not correspond for the sample             spNO.206_g3
# Warning:             The number of frames does not correspond for the sample             spNO.206_l
# Warning:             The number of frames does not correspond for the sample             spNO.206_m
# Warning:             The number of frames does not correspond for the sample             spNO.207_a
# Warning:             The number of frames does not correspond for the sample             spNO.207_a2
# Warning:             The number of frames does not correspond for the sample             spNO.207_b
# Warning:             The number of frames does not correspond for the sample             spNO.207_c4
# Warning:             The number of frames does not correspond for the sample             spNO.207_c5
# Warning:             The number of frames does not correspond for the sample             spNO.207_c6
# Warning:             The number of frames does not correspond for the sample             spNO.207_d
# Warning:             The number of frames does not correspond for the sample             spNO.207_e
# Warning:             The number of frames does not correspond for the sample             spNO.207_h2
# Warning:             The number of frames does not correspond for the sample             spNO.207_h3
# Warning:             The number of frames does not correspond for the sample             spNO.207_i
# Warning:             The number of frames does not correspond for the sample             spNO.207_j2
# Warning:             The number of frames does not correspond for the sample             spNO.207_l
# Warning:             The number of frames does not correspond for the sample             spNO.207_l2
# Warning:             The number of frames does not correspond for the sample             spNO.207_l3
# Warning:             The number of frames does not correspond for the sample             spNO.208_c
# Warning:             The number of frames does not correspond for the sample             spNO.208_c6
# Warning:             The number of frames does not correspond for the sample             spNO.209_m
# Warning:             The number of frames does not correspond for the sample             spNO.210_b2
# Warning:             The number of frames does not correspond for the sample             spNO.210_b3
# Warning:             The number of frames does not correspond for the sample             spNO.210_c2
# Warning:             The number of frames does not correspond for the sample             spNO.210_c3
# Warning:             The number of frames does not correspond for the sample             spNO.210_d
# Warning:             The number of frames does not correspond for the sample             spNO.210_d2
# Warning:             The number of frames does not correspond for the sample             spNO.210_d3
# Warning:             The number of frames does not correspond for the sample             spNO.210_e
# Warning:             The number of frames does not correspond for the sample             spNO.210_f
# Warning:             The number of frames does not correspond for the sample             spNO.210_f2
# Warning:             The number of frames does not correspond for the sample             spNO.210_h
# Warning:             The number of frames does not correspond for the sample             spNO.210_h2
# Warning:             The number of frames does not correspond for the sample             spNO.210_i2
# Warning:             The number of frames does not correspond for the sample             spNO.210_k
# Warning:             The number of frames does not correspond for the sample             spNO.210_k2
# Warning:             The number of frames does not correspond for the sample             spNO.212_b
# Warning:             The number of frames does not correspond for the sample             spNO.212_f
# Warning:             The number of frames does not correspond for the sample             spNO.212_i
# Warning:             The number of frames does not correspond for the sample             spNO.212_i2
# Warning:             The number of frames does not correspond for the sample             spNO.212_j
# Warning:             The number of frames does not correspond for the sample             spNO.212_j2
# Warning:             The number of frames does not correspond for the sample             spNO.213_k
# Warning:             The number of frames does not correspond for the sample             spNO.214_c
# Warning:             The number of frames does not correspond for the sample             spNO.214_j
# Warning:             The number of frames does not correspond for the sample             spNO.215_a3
# Warning:             The number of frames does not correspond for the sample             spNO.215_b5
# Warning:             The number of frames does not correspond for the sample             spNO.215_d
# Warning:             The number of frames does not correspond for the sample             spNO.215_d2
# Warning:             The number of frames does not correspond for the sample             spNO.215_d3
# Warning:             The number of frames does not correspond for the sample             spNO.215_d4
# Warning:             The number of frames does not correspond for the sample             spNO.215_d5
# Warning:             The number of frames does not correspond for the sample             spNO.215_d6
# Warning:             The number of frames does not correspond for the sample             spNO.215_d7
# Warning:             The number of frames does not correspond for the sample             spNO.215_e2
# Warning:             The number of frames does not correspond for the sample             spNO.215_f3
# Warning:             The number of frames does not correspond for the sample             spNO.215_f4
# Warning:             The number of frames does not correspond for the sample             spNO.215_h
# Warning:             The number of frames does not correspond for the sample             spNO.215_i
# Warning:             The number of frames does not correspond for the sample             spNO.215_j
# Warning:             The number of frames does not correspond for the sample             spNO.215_j3
# Warning:             The number of frames does not correspond for the sample             spNO.215_j4
# Warning:             The number of frames does not correspond for the sample             spNO.215_k2
# Warning:             The number of frames does not correspond for the sample             spNO.215_l
# Warning: The offset does not correspond for the sample            spNO.214_c

# %%
# Transpose data to fit the format of mdmo
data = (video.transpose(1, 2, 0) for video in data)

# %%
mdmo_features = tm.calculate_mdmo(df, data)
# Out:
# 0 / 2031
# 10 / 2031
# 20 / 2031
# 30 / 2031
# 40 / 2031
# 50 / 2031
# 60 / 2031
# 70 / 2031
# 80 / 2031
# 90 / 2031
# 100 / 2031
# 110 / 2031
# 120 / 2031
# 130 / 2031
# 140 / 2031
# 150 / 2031
# 160 / 2031
# 170 / 2031
# 180 / 2031
# 190 / 2031
# 200 / 2031
# 210 / 2031
# 220 / 2031
# 230 / 2031
# 240 / 2031
# 250 / 2031
# 260 / 2031
# 270 / 2031
# 280 / 2031
# 290 / 2031
# 300 / 2031
# 310 / 2031
# 320 / 2031
# 330 / 2031
# 340 / 2031
# 350 / 2031
# 360 / 2031
# 370 / 2031
# 380 / 2031
# 390 / 2031
# 400 / 2031
# 410 / 2031
# 420 / 2031
# 430 / 2031
# 440 / 2031
# 450 / 2031
# 460 / 2031
# 470 / 2031
# 480 / 2031
# 490 / 2031
# 500 / 2031
# 510 / 2031
# 520 / 2031
# 530 / 2031
# 540 / 2031
# 550 / 2031
# 560 / 2031
# 570 / 2031
# 580 / 2031
# 590 / 2031
# 600 / 2031
# 610 / 2031
# 620 / 2031
# 630 / 2031
# 640 / 2031
# 650 / 2031
# 660 / 2031
# 670 / 2031
# 680 / 2031
# 690 / 2031
# 700 / 2031
# 710 / 2031
# 720 / 2031
# 730 / 2031
# 740 / 2031
# 750 / 2031
# 760 / 2031
# 770 / 2031
# 780 / 2031
# 790 / 2031
# 800 / 2031
# 810 / 2031
# 820 / 2031
# 830 / 2031
# 840 / 2031
# 850 / 2031
# 860 / 2031
# 870 / 2031
# 880 / 2031
# 890 / 2031
# 900 / 2031
# 910 / 2031
# 920 / 2031
# 930 / 2031
# 940 / 2031
# 950 / 2031
# 960 / 2031
# 970 / 2031
# 980 / 2031
# 990 / 2031
# 1000 / 2031
# 1010 / 2031
# 1020 / 2031
# 1030 / 2031
# 1040 / 2031
# 1050 / 2031
# 1060 / 2031
# 1070 / 2031
# 1080 / 2031
# 1090 / 2031
# 1100 / 2031
# 1110 / 2031
# 1120 / 2031
# 1130 / 2031
# 1140 / 2031
# 1150 / 2031
# 1160 / 2031
# 1170 / 2031
# 1180 / 2031
# 1190 / 2031
# 1200 / 2031
# 1210 / 2031
# 1220 / 2031
# 1230 / 2031
# 1240 / 2031
# 1250 / 2031
# 1260 / 2031
# 1270 / 2031
# 1280 / 2031
# 1290 / 2031
# 1300 / 2031
# 1310 / 2031
# 1320 / 2031
# 1330 / 2031
# 1340 / 2031
# 1350 / 2031
# 1360 / 2031
# 1370 / 2031
# 1380 / 2031
# 1390 / 2031
# 1400 / 2031
# 1410 / 2031
# 1420 / 2031
# 1430 / 2031
# 1440 / 2031
# 1450 / 2031
# 1460 / 2031
# 1470 / 2031
# 1480 / 2031
# 1490 / 2031
# 1500 / 2031
# 1510 / 2031
# 1520 / 2031
# 1530 / 2031
# 1540 / 2031
# 1550 / 2031
# 1560 / 2031
# 1570 / 2031
# 1580 / 2031
# 1590 / 2031
# 1600 / 2031
# 1610 / 2031
# 1620 / 2031
# 1630 / 2031
# 1640 / 2031
# 1650 / 2031
# 1660 / 2031
# 1670 / 2031
# 1680 / 2031
# 1690 / 2031
# 1700 / 2031
# 1710 / 2031
# 1720 / 2031
# 1730 / 2031
# 1740 / 2031
# 1750 / 2031
# 1760 / 2031
# 1770 / 2031
# 1780 / 2031
# 1790 / 2031
# 1800 / 2031
# 1810 / 2031
# 1820 / 2031
# 1830 / 2031
# 1840 / 2031
# 1850 / 2031
# 1860 / 2031
# 1870 / 2031
# 1880 / 2031
# 1890 / 2031
# 1900 / 2031
# 1910 / 2031
# 1920 / 2031
# 1930 / 2031
# 1940 / 2031
# 1950 / 2031
# 1960 / 2031
# 1970 / 2031
# 1980 / 2031
# 1990 / 2031
# 2000 / 2031
# 2010 / 2031
# 2020 / 2031
# 2030 / 2031

# %%
beta = 0.8
mdmo_features[:, :36] = beta * mdmo_features[:, :36]
mdmo_features[:, 36:] = (1 - beta) * mdmo_features[:, 36:]

# %%
mdmo_features = np.load("../../../data/mdmo_cross_dataset.npy")

# %%
class Config(core.Config):
    action_units = utils.dataset_aus["cross"]
    evaluation_fn = [
        partial(utils.MultiLabelF1Score, average="macro"),
        partial(utils.MultiLabelF1Score, average="binary")
    ]
    # Multioutput classifiers for multi-label
    model = partial(MultiOutputClassifier, SVC(C=28))

# %%
out = HandCraftedCrossValidator(Config).validate_n_times(df, mdmo_features)
# Out:
# 100%|█████████████████████████████████████████████| 5/5 [01:33<00:00, 18.61s/it]
# MultiLabelF1Score
# AUS: ['AU1', 'AU2', 'AU4', 'AU5', 'AU6', 'AU7', 'AU9', 'AU10', 'AU12', 'AU14', 'AU15', 'AU17', 'Average']
# 76.6 & 75.6 & 79.4 & 55.8 & 50.1 & 53.9 & 53.6 & 48.6 & 60.7 & 58.5 & 55.7 & 62.5 & 60.9
#
# Datasets:  ['casme', 'casme2', 'samm', 'fourd', 'mmew', 'casme3a', 'Average']
# 62.0 & 63.2 & 57.6 & 60.5 & 61.6 & 58.8 & 60.6
# MultiLabelF1Score
# AUS: ['AU1', 'AU2', 'AU4', 'AU5', 'AU6', 'AU7', 'AU9', 'AU10', 'AU12', 'AU14', 'AU15', 'AU17', 'Average']
# 59.4 & 57.0 & 72.2 & 16.7 & 2.3 & 18.1 & 10.9 & 0.0 & 27.4 & 25.5 & 13.0 & 27.8 & 27.5
#
# Datasets:  ['casme', 'casme2', 'samm', 'fourd', 'mmew', 'casme3a', 'Average']
# 29.5 & 31.7 & 21.1 & 27.5 & 29.1 & 23.3 & 27.0

# %% [markdown]
# # LBP-TOP

# %%
c = datasets.CrossDataset(resize=112, cropped=True)
df = c.data_frame
data = c.data
# Out:
# Warning:             The number of frames does not correspond for the sample             spNO.170_k
# Warning:             The number of frames does not correspond for the sample             spNO.171_e
# Warning:             The number of frames does not correspond for the sample             spNO.171_e2
# Warning:             The number of frames does not correspond for the sample             spNO.171_f
# Warning:             The number of frames does not correspond for the sample             spNO.171_f2
# Warning:             The number of frames does not correspond for the sample             spNO.171_h2
# Warning:             The number of frames does not correspond for the sample             spNO.171_h3
# Warning:             The number of frames does not correspond for the sample             spNO.171_h4
# Warning:             The number of frames does not correspond for the sample             spNO.171_h5
# Warning:             The number of frames does not correspond for the sample             spNO.171_l
# Warning:             The number of frames does not correspond for the sample             spNO.172_f
# Warning:             The number of frames does not correspond for the sample             spNO.172_k
# Warning:             The number of frames does not correspond for the sample             spNO.172_k3
# Warning:             The number of frames does not correspond for the sample             spNO.174_e
# Warning:             The number of frames does not correspond for the sample             spNO.202_m
# Warning:             The number of frames does not correspond for the sample             spNO.202_m2
# Warning:             The number of frames does not correspond for the sample             spNO.206_d
# Warning:             The number of frames does not correspond for the sample             spNO.206_e2
# Warning:             The number of frames does not correspond for the sample             spNO.206_e3
# Warning:             The number of frames does not correspond for the sample             spNO.206_g3
# Warning:             The number of frames does not correspond for the sample             spNO.206_l
# Warning:             The number of frames does not correspond for the sample             spNO.206_m
# Warning:             The number of frames does not correspond for the sample             spNO.207_a
# Warning:             The number of frames does not correspond for the sample             spNO.207_a2
# Warning:             The number of frames does not correspond for the sample             spNO.207_b
# Warning:             The number of frames does not correspond for the sample             spNO.207_c4
# Warning:             The number of frames does not correspond for the sample             spNO.207_c5
# Warning:             The number of frames does not correspond for the sample             spNO.207_c6
# Warning:             The number of frames does not correspond for the sample             spNO.207_d
# Warning:             The number of frames does not correspond for the sample             spNO.207_e
# Warning:             The number of frames does not correspond for the sample             spNO.207_h2
# Warning:             The number of frames does not correspond for the sample             spNO.207_h3
# Warning:             The number of frames does not correspond for the sample             spNO.207_i
# Warning:             The number of frames does not correspond for the sample             spNO.207_j2
# Warning:             The number of frames does not correspond for the sample             spNO.207_l
# Warning:             The number of frames does not correspond for the sample             spNO.207_l2
# Warning:             The number of frames does not correspond for the sample             spNO.207_l3
# Warning:             The number of frames does not correspond for the sample             spNO.208_c
# Warning:             The number of frames does not correspond for the sample             spNO.208_c6
# Warning:             The number of frames does not correspond for the sample             spNO.209_m
# Warning:             The number of frames does not correspond for the sample             spNO.210_b2
# Warning:             The number of frames does not correspond for the sample             spNO.210_b3
# Warning:             The number of frames does not correspond for the sample             spNO.210_c2
# Warning:             The number of frames does not correspond for the sample             spNO.210_c3
# Warning:             The number of frames does not correspond for the sample             spNO.210_d
# Warning:             The number of frames does not correspond for the sample             spNO.210_d2
# Warning:             The number of frames does not correspond for the sample             spNO.210_d3
# Warning:             The number of frames does not correspond for the sample             spNO.210_e
# Warning:             The number of frames does not correspond for the sample             spNO.210_f
# Warning:             The number of frames does not correspond for the sample             spNO.210_f2
# Warning:             The number of frames does not correspond for the sample             spNO.210_h
# Warning:             The number of frames does not correspond for the sample             spNO.210_h2
# Warning:             The number of frames does not correspond for the sample             spNO.210_i2
# Warning:             The number of frames does not correspond for the sample             spNO.210_k
# Warning:             The number of frames does not correspond for the sample             spNO.210_k2
# Warning:             The number of frames does not correspond for the sample             spNO.212_b
# Warning:             The number of frames does not correspond for the sample             spNO.212_f
# Warning:             The number of frames does not correspond for the sample             spNO.212_i
# Warning:             The number of frames does not correspond for the sample             spNO.212_i2
# Warning:             The number of frames does not correspond for the sample             spNO.212_j
# Warning:             The number of frames does not correspond for the sample             spNO.212_j2
# Warning:             The number of frames does not correspond for the sample             spNO.213_k
# Warning:             The number of frames does not correspond for the sample             spNO.214_c
# Warning:             The number of frames does not correspond for the sample             spNO.214_j
# Warning:             The number of frames does not correspond for the sample             spNO.215_a3
# Warning:             The number of frames does not correspond for the sample             spNO.215_b5
# Warning:             The number of frames does not correspond for the sample             spNO.215_d
# Warning:             The number of frames does not correspond for the sample             spNO.215_d2
# Warning:             The number of frames does not correspond for the sample             spNO.215_d3
# Warning:             The number of frames does not correspond for the sample             spNO.215_d4
# Warning:             The number of frames does not correspond for the sample             spNO.215_d5
# Warning:             The number of frames does not correspond for the sample             spNO.215_d6
# Warning:             The number of frames does not correspond for the sample             spNO.215_d7
# Warning:             The number of frames does not correspond for the sample             spNO.215_e2
# Warning:             The number of frames does not correspond for the sample             spNO.215_f3
# Warning:             The number of frames does not correspond for the sample             spNO.215_f4
# Warning:             The number of frames does not correspond for the sample             spNO.215_h
# Warning:             The number of frames does not correspond for the sample             spNO.215_i
# Warning:             The number of frames does not correspond for the sample             spNO.215_j
# Warning:             The number of frames does not correspond for the sample             spNO.215_j3
# Warning:             The number of frames does not correspond for the sample             spNO.215_j4
# Warning:             The number of frames does not correspond for the sample             spNO.215_k2
# Warning:             The number of frames does not correspond for the sample             spNO.215_l
# Warning: The offset does not correspond for the sample            spNO.214_c

# %%
# Transpose data to fit the format of mdmo
data = (video.transpose(1, 2, 0) for video in data)
# Extrapolate using timm for cases with less than 10 frames
data = (video if video.shape[-1] >= 10 else tm.tim(video, 10) for i, video in enumerate(data))

# %%
lbptop_features = tm.calculate_lbptop(df, data)
# Out:
# 0 / 2031
# 30 / 2031
# 60 / 2031
# 90 / 2031
# 120 / 2031
# 150 / 2031
# 180 / 2031
# 210 / 2031
# 240 / 2031
# 270 / 2031
# 300 / 2031
# 330 / 2031
# 360 / 2031
# 390 / 2031
# 420 / 2031
# 450 / 2031
# 480 / 2031
# 510 / 2031
# 540 / 2031
# 570 / 2031
# 600 / 2031
# 630 / 2031
# 660 / 2031
# 690 / 2031
# 720 / 2031
# 750 / 2031
# 780 / 2031
# 810 / 2031
# 840 / 2031
# 870 / 2031
# 900 / 2031
# 930 / 2031
# 960 / 2031
# 990 / 2031
# 1020 / 2031
# 1050 / 2031
# 1080 / 2031
# 1110 / 2031
# 1140 / 2031
# 1170 / 2031
# 1200 / 2031
# 1230 / 2031
# 1260 / 2031
# 1290 / 2031
# 1320 / 2031
# 1350 / 2031
# 1380 / 2031
# 1410 / 2031
# 1440 / 2031
# 1470 / 2031
# 1500 / 2031
# 1530 / 2031
# 1560 / 2031
# 1590 / 2031
# 1620 / 2031
# 1650 / 2031
# 1680 / 2031
# 1710 / 2031
# 1740 / 2031
# 1770 / 2031
# 1800 / 2031
# 1830 / 2031
# 1860 / 2031
# 1890 / 2031
# 1920 / 2031
# 1950 / 2031
# 1980 / 2031
# 2010 / 2031

# %%
lbptop_features = np.load("../../../data/lbptop_cross_dataset.npyss_dataset.npy")

# %%
class Config(core.Config):
    action_units = utils.dataset_aus["cross"]
    evaluation_fn = [
        partial(utils.MultiLabelF1Score, average="macro"),
        partial(utils.MultiLabelF1Score, average="binary")
    ]
    # Multioutput classifiers for multi-label
    model = partial(MultiOutputClassifier, SVC(kernel="poly", gamma="scale"))

# %%
out = HandCraftedCrossValidator(Config).validate_n_times(df, lbptop_features, n_times=5)
# Out:
#   0%|                                                     | 0/5 [00:00<?, ?it/s]/home/tvaranka/anaconda3/envs/python3.10/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1599: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /home/tvaranka/anaconda3/envs/python3.10/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1599: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
#  20%|████████▊                                   | 1/5 [11:08<44:34, 668.64s/it]/home/tvaranka/anaconda3/envs/python3.10/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1599: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /home/tvaranka/anaconda3/envs/python3.10/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1599: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
#  40%|█████████████████▌                          | 2/5 [23:04<34:48, 696.14s/it]/home/tvaranka/anaconda3/envs/python3.10/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1599: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /home/tvaranka/anaconda3/envs/python3.10/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1599: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
#  60%|██████████████████████████▍                 | 3/5 [34:28<23:01, 690.86s/it]/home/tvaranka/anaconda3/envs/python3.10/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1599: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /home/tvaranka/anaconda3/envs/python3.10/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1599: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
#  80%|███████████████████████████████████▏        | 4/5 [45:21<11:16, 676.06s/it]/home/tvaranka/anaconda3/envs/python3.10/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1599: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /home/tvaranka/anaconda3/envs/python3.10/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1599: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# 100%|████████████████████████████████████████████| 5/5 [56:30<00:00, 678.05s/it]
# MultiLabelF1Score
# AUS: ['AU1', 'AU2', 'AU4', 'AU5', 'AU6', 'AU7', 'AU9', 'AU10', 'AU12', 'AU14', 'AU15', 'AU17', 'Average']
# 67.4 & 65.1 & 73.9 & 48.3 & 49.3 & 46.7 & 49.4 & 49.1 & 47.7 & 48.2 & 49.4 & 48.9 & 53.6
#
# Datasets:  ['casme', 'casme2', 'samm', 'fourd', 'mmew', 'casme3a', 'Average']
# 60.9 & 55.8 & 52.4 & 53.8 & 57.4 & 49.8 & 55.0
# MultiLabelF1Score
# AUS: ['AU1', 'AU2', 'AU4', 'AU5', 'AU6', 'AU7', 'AU9', 'AU10', 'AU12', 'AU14', 'AU15', 'AU17', 'Average']
# 41.6 & 36.7 & 62.0 & 0.0 & 0.0 & 0.0 & 1.7 & 0.0 & 0.0 & 3.5 & 0.0 & 0.0 & 12.1
#
# Datasets:  ['casme', 'casme2', 'samm', 'fourd', 'mmew', 'casme3a', 'Average']
# 17.9 & 16.5 & 9.7 & 13.8 & 20.1 & 4.4 & 13.7
